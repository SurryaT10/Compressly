# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from matplotlib import image
import os

# %% [markdown]
# ### Read the image

# %%
im = image.imread(os.getcwd() + '\\sample_images\\test.jpg')
type(im)
# Out:
# numpy.ndarray

# %%
im.shape
# Out:
# (484, 860, 3)

# %% [markdown]
# ### Flattening the image to two dimension

# %%
input_image = im.reshape(im.shape[0] * im.shape[1], 3)

# %%
input_image.shape
# Out:
# (416240, 3)

# %%
kmeans = KMeans(n_clusters=32, random_state=42)

# %%
kmeans.fit(input_image)
# Out:
# KMeans(n_clusters=32, random_state=42)

# %%
mean_colors = kmeans.cluster_centers_

# %%
l = kmeans.labels_
l
# Out:
# array([ 3,  3,  3, ..., 28, 28, 28])

# %% [markdown]
# ### Replacing the original colors by the mean colors

# %%
new_image = np.array([mean_colors[l[i]] for i in range(input_image.shape[0])])
new_image
# Out:
# array([[238.42988251, 233.37522061, 213.14941254],
#        [238.42988251, 233.37522061, 213.14941254],
#        [238.42988251, 233.37522061, 213.14941254],
#        ...,
#        [198.5214095 , 215.83507742, 204.65082755],
#        [198.5214095 , 215.83507742, 204.65082755],
#        [198.5214095 , 215.83507742, 204.65082755]])

# %%
new_image = np.round(new_image).astype(np.uint8)

# %%
new_image = new_image.reshape(im.shape[0],im.shape[1],3)

# %%
plt.imshow(new_image)

# %%
plt.imsave(os.getcwd() + '\\sample_images\\compressed_image.png', new_image)
